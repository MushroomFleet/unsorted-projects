# %% [markdown]
# <a href="https://colab.research.google.com/github/MushroomFleet/unsorted-projects/blob/main/240406_V100_hollowstrawberry_Lora_Trainer_XL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌟 XL Lora Trainer by Hollowstrawberry
#
# ❗ **Colab Premium is recommended.** Ideally you'd be changing the runtime to an A100 and use the maximum batch size.
# However you can still train for free if you load a diffusers model, it will just take much longer.
#
#
# This colab is based on the work of [Kohya-ss](https://github.com/kohya-ss/sd-scripts) and [Linaqruf](https://github.com/Linaqruf/kohya-trainer). Thank you!

# %% [markdown]
# ### ⭕ Disclaimer
# The purpose of this document is to research bleeding-edge technologies in the field of machine learning inference.
# Please read and follow the [Google Colab guidelines](https://research.google.com/colaboratory/faq.html) and its [Terms of Service](https://research.google.com/colaboratory/tos_v3.html).

# %% [markdown]
# | |GitHub|🇬🇧 English|🇪🇸 Spanish|
# |:--|:-:|:-:|:-:|
# | 🏠 **Homepage** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab) | | |
# | 📊 **Dataset Maker** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Dataset_Maker.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Dataset_Maker.ipynb) |
# | ⭐ **Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer.ipynb) | [![Abrir en Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge-spanish.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Spanish_Lora_Trainer.ipynb) |
# | 🌟 **XL Lora Trainer** | [![GitHub](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/github.svg)](https://github.com/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) | [![Open in Colab](https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/assets/colab-badge.svg)](https://colab.research.google.com/github/hollowstrawberry/kohya-colab/blob/main/Lora_Trainer_XL.ipynb) |  |

# %%
import os
import re
import toml
from time import time
from huggingface_hub import HfFileSystem
from IPython.display import Markdown, display

# These carry information from past executions
if "model_url" in globals():
  old_model_url = model_url
else:
  old_model_url = None
if "dependencies_installed" not in globals():
  dependencies_installed = False
if "model_file" not in globals():
  model_file = None

# These may be set by other cells, some are legacy
if "custom_dataset" not in globals():
  custom_dataset = None
if "override_dataset_config_file" not in globals():
  override_dataset_config_file = None
if "override_config_file" not in globals():
  override_config_file = None

COLAB = True
SOURCE = "https://github.com/qaneel/kohya-trainer"
COMMIT = None
BETTER_EPOCH_NAMES = True
LOAD_TRUNCATED_IMAGES = True
try:
  LOWRAM = int(next(line.split()[1] for line in open('/proc/meminfo') if "MemTotal" in line)) / (1024**2) < 15
except:
  LOWRAM = False

#@title ## 🚩 Start Here

#@markdown ### ▶️ Setup
#@markdown Your project name will be the same as the folder containing your images. Spaces aren't allowed.
project_name = "Ducreux-colab" #@param {type:"string"}
#@markdown The folder structure doesn't matter and is purely for comfort. Make sure to always pick the same one. I like organizing by project.
folder_structure = "Organize by project (MyDrive/Loras/project_name/dataset)" #@param ["Organize by category (MyDrive/lora_training/datasets/project_name)", "Organize by project (MyDrive/Loras/project_name/dataset)"]
#@markdown Decide the model that will be downloaded and used for training. You can also choose your own by pasting its download link.
training_model = "Stable Diffusion XL 1.0 base" #@param ["Pony Diffusion V6 XL", "Animagine XL V3", "Stable Diffusion XL 1.0 base"]
optional_custom_training_model_url = "" #@param {type:"string"}
#@markdown Using a diffusers model utilizes less resources. The 3 options above will work with or without diffusers.
load_diffusers = True #@param {type:"boolean"}

if optional_custom_training_model_url:
  model_url = optional_custom_training_model_url
elif "Pony" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/stablediffusionapi/pony-diffusion-v6-xl/"
  else:
    model_url = "https://civitai.com/api/download/models/290640"
  model_file = "/content/ponyDiffusionV6XL.safetensors"
elif "Animagine" in training_model:
  if load_diffusers:
    model_url = "https://huggingface.co/cagliostrolab/animagine-xl-3.0"
  else:
    model_url = "https://civitai.com/api/download/models/293564"
  model_file = "/content/animagineXLV3.safetensors"
else:
  if load_diffusers:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/"
  else:
    model_url = "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors"

if load_diffusers:
  vae_file= "stabilityai/sdxl-vae"
else:
  vae_url = "https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors"
  vae_file = "/content/sdxl_vae.safetensors"


#@markdown ### ▶️ Processing
resolution = 1024 #param {type:"slider", min:768, max:1536, step:128}
caption_extension = ".txt" #param {type:"string"}
#@markdown Shuffling anime tags in place improves learning and prompting. An activation tag goes at the start of every text file and will not be shuffled.<p>
shuffle_tags = True #@param {type:"boolean"}
shuffle_caption = shuffle_tags
activation_tags = "2" #@param [0,1,2,3]
keep_tokens = int(activation_tags)

#@markdown ### ▶️ Steps <p>
#@markdown Your images will repeat this number of times during training. I recommend that your images multiplied by their repeats is between 200 and 400.
num_repeats = 20 #@param {type:"number"}
#@markdown Choose how long you want to train for. A good starting point is around 10 epochs or around 2000 steps.<p>
#@markdown One epoch is a number of steps equal to: your number of images multiplied by their repeats, divided by batch size. <p>
preferred_unit = "Epochs" #@param ["Epochs", "Steps"]
how_many = 10 #@param {type:"number"}
max_train_epochs = how_many if preferred_unit == "Epochs" else None
max_train_steps = how_many if preferred_unit == "Steps" else None
#@markdown Saving more epochs will let you compare your Lora's progress better.
save_every_n_epochs = 1 #@param {type:"number"}
keep_only_last_n_epochs = 10 #@param {type:"number"}
if not save_every_n_epochs:
  save_every_n_epochs = max_train_epochs
if not keep_only_last_n_epochs:
  keep_only_last_n_epochs = max_train_epochs

#@markdown ### ▶️ Learning
#@markdown The learning rate is the most important for your results. If you want to train slower with lots of images, or if your dim and alpha are high, move the unet to 2e-4 or lower. <p>
#@markdown The text encoder helps your Lora learn concepts slightly better. It is recommended to make it half or a fifth of the unet. If you're training a style you can even set it to 0.
unet_lr = 3e-4 #@param {type:"number"}
text_encoder_lr = 6e-5 #@param {type:"number"}
#@markdown The scheduler is the algorithm that guides the learning rate. If you're not sure, pick `constant` and ignore the number. I personally recommend `cosine_with_restarts` with 3 restarts.
lr_scheduler = "cosine_with_restarts" #@param ["constant", "cosine", "cosine_with_restarts", "constant_with_warmup", "linear", "polynomial"]
lr_scheduler_number = 3 #@param {type:"number"}
lr_scheduler_num_cycles = lr_scheduler_number if lr_scheduler == "cosine_with_restarts" else 0
lr_scheduler_power = lr_scheduler_number if lr_scheduler == "polynomial" else 0
#@markdown Steps spent "warming up" the learning rate during training for efficiency. I recommend leaving it at 5%.
lr_warmup_ratio = 0.05 #@param {type:"slider", min:0.0, max:0.2, step:0.01}
lr_warmup_steps = 0
#@markdown Adjusts loss over time, makes learning much more efficient. The paper recommends 5.0, I recommend 8.0 for anime. Higher value makes it less strict. Set to 0 to disable.
min_snr_gamma = 4 #@param {type:"slider", min:4.0, max:16.0, step:0.5}

#@markdown ### ▶️ Structure
#@markdown LoRA is the classic type and good for a variety of purposes. LoCon is good with artstyles as it has more layers to learn more aspects of the dataset.
lora_type = "LoRA" #@param ["LoRA", "LoCon"]

#@markdown Below are some recommended XL values for the following settings:

#@markdown | type | network_dim | network_alpha | conv_dim | conv_alpha |
#@markdown | :---: | :---: | :---: | :---: | :---: |
#@markdown | Regular LoRA | 8 | 4 |   |   |
#@markdown | Style LoCon | 16 | 8 | 16 | 8 |

#@markdown More dim means larger Lora, it can hold more information but more isn't always better.
network_dim = 32 #@param {type:"slider", min:1, max:32, step:1}
network_alpha = 16 #@param {type:"slider", min:1, max:32, step:1}
#@markdown The following two values only apply to the additional layers of LoCon.
conv_dim = 16 #@param {type:"slider", min:1, max:32, step:1}
conv_alpha = 1 #@param {type:"slider", min:1, max:32, step:1}

network_module = "networks.lora"
network_args = None
if lora_type.lower() == "locon":
  network_args = [f"conv_dim={conv_dim}", f"conv_alpha={conv_alpha}"]

#@markdown ### ▶️ Training
#@markdown Adjust these parameters depending on your colab configuration.
#@markdown If you're using the free tier you should select a diffusers model at the top of this cell.
#@markdown
#@markdown Higher batch size is often faster but uses more memory.
train_batch_size = 4 #@param {type:"slider", min:1, max:16, step:1}
#@markdown I have found no substantial difference between sdpa and xformers.
cross_attention = "sdpa" #@param ["sdpa", "xformers"]
#@markdown If you're on an A100 you should enable bf16.
mixed_precision = "fp16" #@param ["bf16", "fp16"]
#@markdown Caching latents to drive will add a 250KB file next to each image but will use considerably less memory.
cache_latents = True #@param {type:"boolean"}
cache_latents_to_drive = True #@param {type:"boolean"}
#@markdown The following option will turn off shuffle_tags and disable text encoder training.
cache_text_encoder_outputs  = False  # @param {type:"boolean"}

#@markdown ### ▶️ Advanced
#@markdown The optimizer is the algorithm used for training. AdanW8Bit is the default and works great, while Prodigy manages learning rate automatically and may have several advantages such as training faster due to needing less steps as well as working better for small datasets.
optimizer = "Prodigy" #@param ["AdamW8bit", "Prodigy", "DAdaptation", "DadaptAdam", "DadaptLion", "AdamW", "Lion", "SGDNesterov", "SGDNesterov8bit", "AdaFactor"]
#@markdown Recommended args for AdamW8bit: `weight_decay=0.1 betas=[0.9,0.99]`<p>
#@markdown Recommended args for Prodigy: `decouple=True weight_decay=0.01 betas=[0.9,0.999] d_coef=2 use_bias_correction=True safeguard_warmup=True`
optimizer_args = "decouple=True weight_decay=0.01 betas=[0.9,0.999] d_coef=2 use_bias_correction=True safeguard_warmup=True" #@param {type:"string"}
optimizer_args = [a.strip() for a in optimizer_args.split(' ') if a]
#@markdown If Dadapt or Prodigy are selected and this box is checked, the following recommended values will override any previous settings:<p>
#@markdown `unet_lr=0.75`, `text_encoder_lr=0.75`, `network_alpha=network_dim`
recommended_values_for_prodigy = True #@param {type:"boolean"}

if any(opt in optimizer.lower() for opt in ["dadapt", "prodigy"]):
  if recommended_values_for_prodigy:
    unet_lr = 0.75
    text_encoder_lr = 0.75
    network_alpha = network_dim

#@markdown ### ▶️ Ready
#@markdown You can now run this cell to cook your Lora. Good luck! <p>


# 👩‍💻 Cool code goes here

root_dir = "/content" if COLAB else "~/Loras"
deps_dir = os.path.join(root_dir, "deps")
repo_dir = os.path.join(root_dir, "kohya-trainer")

if "/Loras" in folder_structure:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/Loras") if COLAB else root_dir
  log_folder    = os.path.join(main_dir, "_logs")
  config_folder = os.path.join(main_dir, project_name)
  images_folder = os.path.join(main_dir, project_name, "dataset")
  output_folder = os.path.join(main_dir, project_name, "output")
else:
  main_dir      = os.path.join(root_dir, "drive/MyDrive/lora_training") if COLAB else root_dir
  images_folder = os.path.join(main_dir, "datasets", project_name)
  output_folder = os.path.join(main_dir, "output", project_name)
  config_folder = os.path.join(main_dir, "config", project_name)
  log_folder    = os.path.join(main_dir, "log")

config_file = os.path.join(config_folder, "training_config.toml")
dataset_config_file = os.path.join(config_folder, "dataset_config.toml")
accelerate_config_file = os.path.join(repo_dir, "accelerate_config/config.yaml")

def install_dependencies():
  os.chdir(root_dir)
  # !git clone {SOURCE} {repo_dir}
  os.chdir(repo_dir)
  if COMMIT:
    # !git reset --hard {COMMIT}
  # !wget https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/train_network_xl_wrapper.py -q -O train_network_xl_wrapper.py
  # !wget https://raw.githubusercontent.com/hollowstrawberry/kohya-colab/main/dracula.py -q -O dracula.py

  # !apt -y update -qq
  # !apt -y install aria2 -qq
  # !pip install torch==2.2.1+cu121 accelerate==0.19.0 transformers==4.30.2 diffusers==0.18.2 bitsandbytes==0.40.0.post4 opencv-python==4.7.0.68 jax==0.4.23 jaxlib==0.4.23
  # !pip install pytorch-lightning==1.9.0 voluptuous==0.13.1 toml==0.10.2 ftfy==6.1.1 einops==0.6.0 safetensors pygments
  # !pip install huggingface-hub==0.20.3 invisible-watermark==0.2.0 open-clip-torch==2.20.0 dadaptation==3.1 prodigyopt==1.0 lion-pytorch==0.1.2
  # !pip install -e .
  if cross_attention == "xformers":
    # !pip install -q xformers==0.0.26.dev778

  # patch kohya for minor stuff
  if LOWRAM:
    # !sed -i "s@cpu@cuda@" library/model_util.py
  if LOAD_TRUNCATED_IMAGES:
    # !sed -i 's/from PIL import Image/from PIL import Image, ImageFile\nImageFile.LOAD_TRUNCATED_IMAGES=True/g' library/train_util.py # fix truncated jpegs error
  if BETTER_EPOCH_NAMES:
    # !sed -i 's/{:06d}/{:02d}/g' library/train_util.py # make epoch names shorter
    # !sed -i 's/"." + args.save_model_as)/"-{:02d}.".format(num_train_epochs) + args.save_model_as)/g' train_network.py # name of the last epoch will match the rest

  from accelerate.utils import write_basic_config
  if not os.path.exists(accelerate_config_file):
    write_basic_config(save_location=accelerate_config_file)

  os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
  os.environ["BITSANDBYTES_NOWELCOME"] = "1"
  os.environ["SAFETENSORS_FAST_GPU"] = "1"

def validate_dataset():
  global lr_warmup_steps, lr_warmup_ratio, caption_extension, keep_tokens
  supported_types = (".png", ".jpg", ".jpeg", ".webp", ".bmp")

  print("\n💿 Checking dataset...")
  if not project_name.strip() or any(c in project_name for c in " .()\"'\\/"):
    print("💥 Error: Please choose a valid project name.")
    return

  if custom_dataset:
    try:
      datconf = toml.loads(custom_dataset)
      datasets = [d for d in datconf["datasets"][0]["subsets"]]
    except:
      print(f"💥 Error: Your custom dataset is invalid or contains an error! Please check the original template.")
      return
    reg = [d.get("image_dir") for d in datasets if d.get("is_reg", False)]
    datasets_dict = {d["image_dir"]: d["num_repeats"] for d in datasets}
    folders = datasets_dict.keys()
    files = [f for folder in folders for f in os.listdir(folder)]
    images_repeats = {folder: (len([f for f in os.listdir(folder) if f.lower().endswith(supported_types)]), datasets_dict[folder]) for folder in folders}
  else:
    reg = []
    folders = [images_folder]
    files = os.listdir(images_folder)
    images_repeats = {images_folder: (len([f for f in files if f.lower().endswith(supported_types)]), num_repeats)}

  for folder in folders:
    if not os.path.exists(folder):
      print(f"💥 Error: The folder {folder.replace('/content/drive/', '')} doesn't exist.")
      return
  for folder, (img, rep) in images_repeats.items():
    if not img:
      print(f"💥 Error: Your {folder.replace('/content/drive/', '')} folder is empty.")
      return
  for f in files:
    if not f.lower().endswith((".txt", ".npz")) and not f.lower().endswith(supported_types):
      print(f"💥 Error: Invalid file in dataset: \"{f}\". Aborting.")
      return

  if not [txt for txt in files if txt.lower().endswith(".txt")]:
    caption_extension = ""

  pre_steps_per_epoch = sum(img*rep for (img, rep) in images_repeats.values())
  steps_per_epoch = pre_steps_per_epoch/train_batch_size
  total_steps = max_train_steps or int(max_train_epochs*steps_per_epoch)
  estimated_epochs = int(total_steps/steps_per_epoch)
  lr_warmup_steps = int(total_steps*lr_warmup_ratio)

  for folder, (img, rep) in images_repeats.items():
    print("📁"+folder.replace("/content/drive/", "") + (" (Regularization)" if folder in reg else ""))
    print(f"📈 Found {img} images with {rep} repeats, equaling {img*rep} steps.")
  print(f"📉 Divide {pre_steps_per_epoch} steps by {train_batch_size} batch size to get {steps_per_epoch} steps per epoch.")
  if max_train_epochs:
    print(f"🔮 There will be {max_train_epochs} epochs, for around {total_steps} total training steps.")
  else:
    print(f"🔮 There will be {total_steps} steps, divided into {estimated_epochs} epochs and then some.")

  if total_steps > 10000:
    print("💥 Error: Your total steps are too high. You probably made a mistake. Aborting...")
    return

  return True

def create_config():
  global dataset_config_file, config_file, model_file

  if override_config_file:
    config_file = override_config_file
    print(f"\n⭕ Using custom config file {config_file}")
  else:
    config_dict = {
      "network_arguments": {
        "unet_lr": unet_lr,
        "text_encoder_lr": text_encoder_lr if not cache_text_encoder_outputs else 0,
        "network_dim": network_dim,
        "network_alpha": network_alpha,
        "network_module": network_module,
        "network_args": network_args,
        "network_train_unet_only": text_encoder_lr == 0 or cache_text_encoder_outputs,
      },
      "optimizer_arguments": {
        "learning_rate": unet_lr,
        "lr_scheduler": lr_scheduler,
        "lr_scheduler_num_cycles": lr_scheduler_num_cycles if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power": lr_scheduler_power if lr_scheduler == "polynomial" else None,
        "lr_warmup_steps": lr_warmup_steps if lr_scheduler != "constant" else None,
        "optimizer_type": optimizer,
        "optimizer_args": optimizer_args if optimizer_args else None,
      },
      "training_arguments": {
        "pretrained_model_name_or_path": model_file,
        "vae": vae_file,
        "max_train_steps": max_train_steps,
        "max_train_epochs": max_train_epochs,
        "train_batch_size": train_batch_size,
        "seed": 42,
        "max_token_length": 225,
        "xformers": cross_attention == "xformers",
        "sdpa": cross_attention == "sdpa",
        "min_snr_gamma": min_snr_gamma if min_snr_gamma > 0 else None,
        "lowram": LOWRAM,
        "no_half_vae": True,
        "gradient_checkpointing": True,
        "gradient_accumulation_steps": 1,
        "max_data_loader_n_workers": 8,
        "persistent_data_loader_workers": True,
        "mixed_precision": mixed_precision,
        "full_bf16": mixed_precision == "bf16",
        "cache_latents": cache_latents,
        "cache_latents_to_disk": cache_latents_to_drive,
        "cache_text_encoder_outputs": cache_text_encoder_outputs,
        "min_timestep": 0,
        "max_timestep": 1000,
        "prior_loss_weight": 1.0,
      },
      "saving_arguments": {
        "save_precision": "fp16",
        "save_model_as": "safetensors",
        "save_every_n_epochs": save_every_n_epochs,
        "save_last_n_epochs": keep_only_last_n_epochs,
        "output_name": project_name,
        "output_dir": output_folder,
        "log_prefix": project_name,
        "logging_dir": log_folder,
      }
    }

    for key in config_dict:
      if isinstance(config_dict[key], dict):
        config_dict[key] = {k: v for k, v in config_dict[key].items() if v is not None}

    with open(config_file, "w") as f:
      f.write(toml.dumps(config_dict))
    print(f"\n📄 Config saved to {config_file}")

  if override_dataset_config_file:
    dataset_config_file = override_dataset_config_file
    print(f"⭕ Using custom dataset config file {dataset_config_file}")
  else:
    dataset_config_dict = {
      "general": {
        "resolution": resolution,
        "shuffle_caption": shuffle_caption and not cache_text_encoder_outputs,
        "keep_tokens": keep_tokens,
        "flip_aug": False,
        "caption_extension": caption_extension,
        "enable_bucket": True,
        "bucket_no_upscale": False,
        "bucket_reso_steps": 64,
        "min_bucket_reso": 256,
        "max_bucket_reso": 4096,
      },
      "datasets": toml.loads(custom_dataset)["datasets"] if custom_dataset else [
        {
          "subsets": [
            {
              "num_repeats": num_repeats,
              "image_dir": images_folder,
              "class_tokens": None if caption_extension else project_name
            }
          ]
        }
      ]
    }

    for key in dataset_config_dict:
      if isinstance(dataset_config_dict[key], dict):
        dataset_config_dict[key] = {k: v for k, v in dataset_config_dict[key].items() if v is not None}

    with open(dataset_config_file, "w") as f:
      f.write(toml.dumps(dataset_config_dict))
    print(f"📄 Dataset config saved to {dataset_config_file}")

def download_model():
  global old_model_url, model_url, model_file, vae_url, vae_file
  real_model_url = model_url.strip()

  if load_diffusers:
    if 'huggingface.co' in real_model_url:
        match = re.search(r'huggingface\.co/([^/]+)/([^/]+)', real_model_url)
        if match:
            username = match.group(1)
            model_name = match.group(2)
            model_file = f"{username}/{model_name}"
            fs = HfFileSystem()
            existing_folders = set(fs.ls(model_file, detail=False))
            necessary_folders = [ "scheduler", "text_encoder", "text_encoder_2", "tokenizer", "tokenizer_2", "unet", "vae" ]
            if all(f"{model_file}/{folder}" in existing_folders for folder in necessary_folders):
              print("🍃 Diffusers model identified.")
              return True
    print("🍃 Failed to load Diffusers model.")

  if not model_file:
    if real_model_url.lower().endswith((".ckpt", ".safetensors")):
      model_file = f"/content{real_model_url[real_model_url.rfind('/'):]}"
    else:
      model_file = "/content/downloaded_model.safetensors"
      if os.path.exists(model_file):
        # !rm "{model_file}"

  if m := re.search(r"(?:https?://)?(?:www\.)?huggingface\.co/[^/]+/[^/]+/blob", model_url):
    real_model_url = real_model_url.replace("blob", "resolve")
  elif m := re.search(r"(?:https?://)?(?:www\\.)?civitai\.com/models/([0-9]+)(/[A-Za-z0-9-_]+)?", model_url):
    if m.group(2):
      model_file = f"/content{m.group(2)}.safetensors"
    if m := re.search(r"modelVersionId=([0-9]+)", model_url):
      real_model_url = f"https://civitai.com/api/download/models/{m.group(1)}"
    else:
      raise ValueError("optional_custom_training_model_url contains a civitai link, but the link doesn't include a modelVersionId. You can also right click the download button to copy the direct download link.")

  # !aria2c "{real_model_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{model_file}"

  if not os.path.exists(vae_file):
    # !aria2c "{vae_url}" --console-log-level=warn -c -s 16 -x 16 -k 10M -d / -o "{vae_file}"

  if model_file.lower().endswith(".safetensors"):
    from safetensors.torch import load_file as load_safetensors
    try:
      test = load_safetensors(model_file)
      del test
    except:
      #if "HeaderTooLarge" in str(e):
      new_model_file = os.path.splitext(model_file)[0]+".ckpt"
      # !mv "{model_file}" "{new_model_file}"
      model_file = new_model_file
      print(f"Renamed model to {os.path.splitext(model_file)[0]}.ckpt")

  if model_file.lower().endswith(".ckpt"):
    from torch import load as load_ckpt
    try:
      test = load_ckpt(model_file)
      del test
    except:
      return False

  return True

def main():
  global dependencies_installed

  if COLAB and not os.path.exists('/content/drive'):
    from google.colab import drive
    print("📂 Connecting to Google Drive...")
    drive.mount('/content/drive')

  for dir in (main_dir, deps_dir, repo_dir, log_folder, images_folder, output_folder, config_folder):
    os.makedirs(dir, exist_ok=True)

  if not validate_dataset():
    return

  if not dependencies_installed:
    print("\n🏭 Installing dependencies...\n")
    t0 = time()
    install_dependencies()
    t1 = time()
    dependencies_installed = True
    print(f"\n✅ Installation finished in {int(t1-t0)} seconds.")
  else:
    print("\n✅ Dependencies already installed.")

  if old_model_url != model_url or not model_file or not os.path.exists(model_file):
    print("\n🔄 Downloading model...")
    if not download_model():
      print("\n💥 Error: The model you selected is invalid or corrupted, or couldn't be downloaded. You can use a civitai or huggingface link, or any direct download link.")
      return
    print()
  else:
    print("\n🔄 Model already downloaded.\n")

  create_config()

  print("\n⭐ Starting trainer...\n")
  os.chdir(repo_dir)

  # !accelerate launch --quiet --config_file={accelerate_config_file} --num_cpu_threads_per_process=1 train_network_xl_wrapper.py --dataset_config={dataset_config_file} --config_file={config_file}

  if not get_ipython().__dict__['user_ns']['_exit_code']:
    display(Markdown("### ✅ Done! [Go download your Lora from Google Drive](https://drive.google.com/drive/my-drive)\n"
                     "### There will be several files, you should try the latest version (the file with the largest number next to it)"))

main()
# Out:
# 📂 Connecting to Google Drive...
# Mounted at /content/drive
#
# 💿 Checking dataset...
# 📁MyDrive/Loras/Ducreux-colab/dataset
# 📈 Found 12 images with 20 repeats, equaling 240 steps.
# 📉 Divide 240 steps by 4 batch size to get 60.0 steps per epoch.
# 🔮 There will be 10 epochs, for around 600 total training steps.
#
# 🏭 Installing dependencies...
#
# Cloning into '/content/kohya-trainer'...
# remote: Enumerating objects: 2441, done.
# remote: Counting objects: 100% (1045/1045), done.
# remote: Compressing objects: 100% (273/273), done.
# remote: Total 2441 (delta 907), reused 772 (delta 772), pack-reused 1396
# Receiving objects: 100% (2441/2441), 4.13 MiB | 15.33 MiB/s, done.
# Resolving deltas: 100% (1632/1632), done.
# 45 packages can be upgraded. Run 'apt list --upgradable' to see them.
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Requirement already satisfied: torch==2.2.1+cu121 in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Collecting accelerate==0.19.0
#   Downloading accelerate-0.19.0-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 2.0 MB/s eta 0:00:00
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 32.6 MB/s eta 0:00:00
# Collecting diffusers==0.18.2
#   Downloading diffusers-0.18.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 74.3 MB/s eta 0:00:00
# Collecting bitsandbytes==0.40.0.post4
#   Downloading bitsandbytes-0.40.0.post4-py3-none-any.whl (101.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 MB 7.2 MB/s eta 0:00:00
# Collecting opencv-python==4.7.0.68
#   Downloading opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 6.7 MB/s eta 0:00:00
# Collecting jax==0.4.23
#   Downloading jax-0.4.23-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.3 MB/s eta 0:00:00
# Collecting jaxlib==0.4.23
#   Downloading jaxlib-0.4.23-cp310-cp310-manylinux2014_x86_64.whl (77.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.2/77.2 MB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1+cu121) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1+cu121) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1+cu121) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1+cu121) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1+cu121) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1+cu121) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1+cu121)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1+cu121)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1+cu121)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1+cu121)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1+cu121)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1+cu121)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1+cu121)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1+cu121)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1+cu121)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1+cu121)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1+cu121)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1+cu121) (2.2.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.19.0) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (0.20.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (4.66.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2) (9.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers==0.18.2) (7.1.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23) (1.11.4)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1+cu121)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers==0.18.2) (3.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.1+cu121) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.1+cu121) (1.3.0)
# Installing collected packages: tokenizers, bitsandbytes, opencv-python, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jaxlib, jax, transformers, nvidia-cusolver-cu12, diffusers, accelerate
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.26+cuda12.cudnn89
#     Uninstalling jaxlib-0.4.26+cuda12.cudnn89:
#       Successfully uninstalled jaxlib-0.4.26+cuda12.cudnn89
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.26
#     Uninstalling jax-0.4.26:
#       Successfully uninstalled jax-0.4.26
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# Successfully installed accelerate-0.19.0 bitsandbytes-0.40.0.post4 diffusers-0.18.2 jax-0.4.23 jaxlib-0.4.23 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 opencv-python-4.7.0.68 tokenizers-0.13.3 transformers-4.30.2
# Collecting pytorch-lightning==1.9.0
#   Downloading pytorch_lightning-1.9.0-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 4.8 MB/s eta 0:00:00
# Collecting voluptuous==0.13.1
#   Downloading voluptuous-0.13.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: toml==0.10.2 in /usr/local/lib/python3.10/dist-packages (0.10.2)
# Collecting ftfy==6.1.1
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.1 MB/s eta 0:00:00
# Collecting einops==0.6.0
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (2.16.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.0) (1.25.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.0) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.0) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.0) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.0) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning==1.9.0)
#   Downloading torchmetrics-1.3.2-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.0) (24.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.0) (4.11.0)
# Collecting lightning-utilities>=0.4.2 (from pytorch-lightning==1.9.0)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.1.1) (0.2.13)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (3.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.4.2->pytorch-lightning==1.9.0) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (3.13.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning==1.9.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->pytorch-lightning==1.9.0) (12.4.127)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->pytorch-lightning==1.9.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning==1.9.0) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->pytorch-lightning==1.9.0) (1.3.0)
# Installing collected packages: voluptuous, lightning-utilities, ftfy, einops, torchmetrics, pytorch-lightning
# Successfully installed einops-0.6.0 ftfy-6.1.1 lightning-utilities-0.11.2 pytorch-lightning-1.9.0 torchmetrics-1.3.2 voluptuous-0.13.1
# Requirement already satisfied: huggingface-hub==0.20.3 in /usr/local/lib/python3.10/dist-packages (0.20.3)
# Collecting invisible-watermark==0.2.0
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.6 MB/s eta 0:00:00
# Collecting open-clip-torch==2.20.0
#   Downloading open_clip_torch-2.20.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 54.9 MB/s eta 0:00:00
# Collecting dadaptation==3.1
#   Downloading dadaptation-3.1.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting prodigyopt==1.0
#   Downloading prodigyopt-1.0-py3-none-any.whl (5.5 kB)
# Collecting lion-pytorch==0.1.2
#   Downloading lion_pytorch-0.1.2-py3-none-any.whl (4.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.3) (3.13.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.3) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.3) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.3) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.3) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.3) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub==0.20.3) (24.0)
# Requirement already satisfied: Pillow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0) (9.4.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0) (1.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0) (1.25.2)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0) (4.7.0.68)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from invisible-watermark==0.2.0) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (0.17.1+cu121)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (2023.12.25)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (6.1.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (0.1.99)
# Requirement already satisfied: protobuf<4 in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0) (3.20.3)
# Collecting timm (from open-clip-torch==2.20.0)
#   Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.9 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->invisible-watermark==0.2.0) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->invisible-watermark==0.2.0) (12.4.127)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->open-clip-torch==2.20.0) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub==0.20.3) (2024.2.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->open-clip-torch==2.20.0) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->invisible-watermark==0.2.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->invisible-watermark==0.2.0) (1.3.0)
# Building wheels for collected packages: dadaptation
#   Building wheel for dadaptation (pyproject.toml) ... done
#   Created wheel for dadaptation: filename=dadaptation-3.1-py3-none-any.whl size=22788 sha256=a7b5664fec987dd1123b16f151b3c3e383c0f5eeed74a20ba5e6b951c9bbf999
#   Stored in directory: /root/.cache/pip/wheels/34/25/92/b7708738900a69a166f41de56c776039b5a05599b36075c34f
# Successfully built dadaptation
# Installing collected packages: prodigyopt, dadaptation, lion-pytorch, invisible-watermark, timm, open-clip-torch
# Successfully installed dadaptation-3.1 invisible-watermark-0.2.0 lion-pytorch-0.1.2 open-clip-torch-2.20.0 prodigyopt-1.0 timm-0.9.16
# Obtaining file:///content/kohya-trainer
#   Preparing metadata (setup.py) ... done
# Installing collected packages: library
#   Running setup.py develop for library
# Successfully installed library-0.0.0
#
# ✅ Installation finished in 165 seconds.
#
# 🔄 Downloading model...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 🍃 Diffusers model identified.
#
#
# 📄 Config saved to /content/drive/MyDrive/Loras/Ducreux-colab/training_config.toml
# 📄 Dataset config saved to /content/drive/MyDrive/Loras/Ducreux-colab/dataset_config.toml
#
# ⭐ Starting trainer...
#
# Loading settings from /content/drive/MyDrive/Loras/Ducreux-colab/training_config.toml...
# /content/drive/MyDrive/Loras/Ducreux-colab/training_config
# prepare tokenizers
# vocab.json: 100% 961k/961k [00:00<00:00, 15.9MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 7.24MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.64MB/s]
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 5.11MB/s]
# vocab.json: 100% 862k/862k [00:00<00:00, 8.83MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 5.14MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.61MB/s]
# tokenizer_config.json: 100% 904/904 [00:00<00:00, 7.24MB/s]
# update token length: 225
# Loading dataset config from /content/drive/MyDrive/Loras/Ducreux-colab/dataset_config.toml
# prepare images.
# found directory /content/drive/MyDrive/Loras/Ducreux-colab/dataset contains 12 image files
# 240 train images with repeating.
# 0 reg images.
# no regularization images / 正則化画像が見つかりませんでした
# [Dataset 0]
#   batch_size: 4
#   resolution: (1024, 1024)
#   enable_bucket: True
#   min_bucket_reso: 256
#   max_bucket_reso: 4096
#   bucket_reso_steps: 64
#   bucket_no_upscale: False
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/drive/MyDrive/Loras/Ducreux-colab/dataset"
#     image_count: 12
#     num_repeats: 20
#     shuffle_caption: True
#     keep_tokens: 2
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epoches: 0
#     caption_tag_dropout_rate: 0.0
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1,
#     token_warmup_step: 0,
#     is_reg: False
#     class_tokens: None
#     caption_extension: .txt
#
#
# [Dataset 0]
# loading image sizes.
# 100% 12/12 [00:04<00:00,  2.59it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (1024, 1024), count: 240
# mean ar error (without repeats): 0.0
# noise_offset is set to 0.0357 / noise_offsetが0.0357に設定されました
# preparing accelerator
# loading model for process 0/1
# load Diffusers pretrained models: stabilityai/stable-diffusion-xl-base-1.0, variant=fp16
# model_index.json: 100% 609/609 [00:00<00:00, 2.73MB/s]
# Fetching 23 files:   0% 0/23 [00:00<?, ?it/s]
# text_encoder/config.json: 100% 565/565 [00:00<00:00, 3.50MB/s]
#
# tokenizer_2/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
# scheduler/scheduler_config.json: 100% 479/479 [00:00<00:00, 2.65MB/s]
# Fetching 23 files:   9% 2/23 [00:00<00:05,  4.12it/s]
#
# text_encoder_2/config.json: 100% 575/575 [00:00<00:00, 3.80MB/s]
#
#
# tokenizer_2/special_tokens_map.json: 100% 460/460 [00:00<00:00, 2.75MB/s]
#
#
# tokenizer_2/tokenizer_config.json: 100% 725/725 [00:00<00:00, 4.34MB/s]
#
#
# tokenizer_2/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
# unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 10.6MB/s]
#
# tokenizer_2/merges.txt: 100% 525k/525k [00:00<00:00, 2.44MB/s]
#
# model.onnx:   0% 0.00/1.04M [00:00<?, ?B/s]
#
#
# model.fp16.safetensors:   0% 0.00/246M [00:00<?, ?B/s]
#
#
#
# model.fp16.safetensors:   0% 0.00/1.39G [00:00<?, ?B/s]
#
#
#
#
# model.onnx: 100% 1.04M/1.04M [00:00<00:00, 14.7MB/s]
#
#
# tokenizer_2/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 5.72MB/s]
#
# vae/config.json: 100% 642/642 [00:00<00:00, 2.62MB/s]
#
#
#
# model.fp16.safetensors:   4% 10.5M/246M [00:00<00:03, 61.1MB/s]
# diffusion_pytorch_model.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
# model.onnx:   0% 0.00/7.29M [00:00<?, ?B/s]
#
#
#
#
#
# vae_1_0/config.json: 100% 607/607 [00:00<00:00, 3.73MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   0% 0.00/5.14G [00:00<?, ?B/s]
#
#
#
# model.fp16.safetensors:   1% 10.5M/1.39G [00:00<00:24, 57.3MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model.onnx:   0% 0.00/198M [00:00<?, ?B/s]
#
#
#
#
# model.onnx:   2% 10.5M/493M [00:01<01:04, 7.47MB/s]
#
#
# model.fp16.safetensors:   9% 21.0M/246M [00:01<00:19, 11.8MB/s]
# diffusion_pytorch_model.fp16.safetensors:   6% 10.5M/167M [00:01<00:21, 7.28MB/s]
#
# model.onnx: 100% 7.29M/7.29M [00:01<00:00, 4.78MB/s]
#
#
#
#
# model.onnx:   4% 21.0M/493M [00:01<00:32, 14.4MB/s]
#
#
# model.onnx: 100% 7.29M/7.29M [00:01<00:00, 4.61MB/s]
#
#
#
#
# model.fp16.safetensors:   2% 21.0M/1.39G [00:01<02:11, 10.4MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   6% 10.5M/167M [00:01<00:22, 6.89MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   0% 10.5M/5.14G [00:01<13:17, 6.43MB/s]
# diffusion_pytorch_model.fp16.safetensors:  13% 21.0M/167M [00:01<00:10, 14.4MB/s]
#
#
#
#
# model.onnx:   6% 31.5M/493M [00:01<00:20, 22.5MB/s]
#
#
# model.fp16.safetensors:  17% 41.9M/246M [00:01<00:07, 25.6MB/s]
#
#
#
#
#
#
#
# model.onnx:   5% 10.5M/198M [00:01<00:27, 6.73MB/s]
#
# model.onnx:   0% 0.00/137M [00:00<?, ?B/s]
#
#
#
# model.fp16.safetensors:   2% 31.5M/1.39G [00:02<01:27, 15.6MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  13% 21.0M/167M [00:01<00:11, 13.2MB/s]
#
#
#
#
# model.onnx:   9% 41.9M/493M [00:02<00:17, 25.5MB/s]
#
#
# model.fp16.safetensors:  21% 52.4M/246M [00:02<00:06, 28.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   0% 21.0M/5.14G [00:02<07:11, 11.9MB/s]
# diffusion_pytorch_model.fp16.safetensors:  19% 31.5M/167M [00:02<00:07, 18.5MB/s]
#
# model.onnx:   8% 10.5M/137M [00:00<00:02, 53.8MB/s]
#
#
#
#
#
#
#
# model.onnx:  11% 21.0M/198M [00:01<00:14, 12.3MB/s]
#
#
#
#
# model.onnx:  11% 52.4M/493M [00:02<00:14, 31.1MB/s]
#
#
#
# model.fp16.safetensors:   3% 41.9M/1.39G [00:02<01:09, 19.5MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  19% 31.5M/167M [00:02<00:07, 18.7MB/s]
#
#
# model.fp16.safetensors:  26% 62.9M/246M [00:02<00:05, 33.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   1% 31.5M/5.14G [00:02<04:51, 17.5MB/s]
# diffusion_pytorch_model.fp16.safetensors:  25% 41.9M/167M [00:02<00:05, 22.0MB/s]
#
# model.onnx:  15% 21.0M/137M [00:00<00:03, 38.6MB/s]
#
#
#
#
#
#
#
# model.onnx:  16% 31.5M/198M [00:02<00:09, 18.2MB/s]
#
#
#
#
# model.onnx:  13% 62.9M/493M [00:02<00:12, 35.6MB/s]
#
#
# model.fp16.safetensors:  30% 73.4M/246M [00:02<00:04, 35.5MB/s]
#
#
#
# model.fp16.safetensors:   4% 52.4M/1.39G [00:02<00:56, 23.5MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   1% 41.9M/5.14G [00:02<03:39, 23.2MB/s]
#
#
#
#
#
#
#
# model.onnx:  21% 41.9M/198M [00:02<00:06, 25.6MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  25% 41.9M/167M [00:02<00:05, 22.9MB/s]
#
# model.onnx:  23% 31.5M/137M [00:00<00:02, 38.3MB/s]
# diffusion_pytorch_model.fp16.safetensors:  31% 52.4M/167M [00:02<00:04, 25.9MB/s]
#
#
#
#
# model.onnx:  15% 73.4M/493M [00:02<00:11, 37.7MB/s]
#
#
# model.fp16.safetensors:  34% 83.9M/246M [00:02<00:04, 38.9MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   1% 52.4M/5.14G [00:02<03:03, 27.7MB/s]
#
#
#
# model.fp16.safetensors:   5% 62.9M/1.39G [00:02<00:48, 27.4MB/s]
#
#
#
#
#
#
#
# model.onnx:  26% 52.4M/198M [00:02<00:04, 30.3MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  31% 52.4M/167M [00:02<00:04, 27.3MB/s]
# diffusion_pytorch_model.fp16.safetensors:  38% 62.9M/167M [00:02<00:03, 32.7MB/s]
#
# model.onnx:  31% 41.9M/137M [00:00<00:02, 45.3MB/s]
#
#
#
#
# model.onnx:  17% 83.9M/493M [00:02<00:09, 43.8MB/s]
#
#
#
# model.fp16.safetensors:   5% 73.4M/1.39G [00:03<00:37, 35.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   1% 62.9M/5.14G [00:02<02:26, 34.7MB/s]
#
#
# model.fp16.safetensors:  38% 94.4M/246M [00:03<00:03, 41.7MB/s]
# diffusion_pytorch_model.fp16.safetensors:  44% 73.4M/167M [00:02<00:02, 40.0MB/s]
#
#
#
#
#
#
#
# model.onnx:  32% 62.9M/198M [00:02<00:03, 35.6MB/s]
#
#
#
#
# model.onnx:  19% 94.4M/493M [00:03<00:08, 49.2MB/s]
#
# model.onnx:  38% 52.4M/137M [00:01<00:01, 51.4MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  38% 62.9M/167M [00:02<00:03, 32.9MB/s]
#
#
#
# model.fp16.safetensors:   6% 83.9M/1.39G [00:03<00:33, 39.0MB/s]
# diffusion_pytorch_model.fp16.safetensors:  50% 83.9M/167M [00:03<00:01, 43.1MB/s]
#
#
#
# model.fp16.safetensors:   7% 94.4M/1.39G [00:03<00:28, 45.1MB/s]
# diffusion_pytorch_model.fp16.safetensors:  56% 94.4M/167M [00:03<00:01, 45.4MB/s]
#
#
# model.fp16.safetensors:  43% 105M/246M [00:03<00:04, 32.5MB/s]
#
#
#
#
#
#
#
# model.onnx:  37% 73.4M/198M [00:03<00:04, 29.8MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  44% 73.4M/167M [00:03<00:03, 23.6MB/s]
#
# model.onnx:  46% 62.9M/137M [00:02<00:03, 21.4MB/s]
#
#
#
#
# model.onnx:  21% 105M/493M [00:04<00:18, 20.8MB/s]
#
#
#
# model.fp16.safetensors:   8% 105M/1.39G [00:05<01:31, 14.1MB/s]
# diffusion_pytorch_model.fp16.safetensors:  63% 105M/167M [00:07<00:08, 7.63MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   1% 73.4M/5.14G [00:07<13:45, 6.13MB/s]
#
#
# model.fp16.safetensors:  47% 115M/246M [00:07<00:18, 7.02MB/s]
#
#
#
#
#
#
#
# model.onnx:  42% 83.9M/198M [00:07<00:17, 6.69MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  50% 83.9M/167M [00:07<00:12, 6.65MB/s]
#
# model.onnx:  54% 73.4M/137M [00:05<00:09, 6.83MB/s]
#
#
#
#
# model.onnx:  23% 115M/493M [00:07<00:52, 7.25MB/s]
#
#
#
# model.fp16.safetensors:   8% 115M/1.39G [00:07<02:40, 7.93MB/s]
# diffusion_pytorch_model.fp16.safetensors:  69% 115M/167M [00:08<00:06, 8.63MB/s]
#
#
# model.fp16.safetensors:  51% 126M/246M [00:08<00:14, 8.56MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   2% 83.9M/5.14G [00:08<11:00, 7.64MB/s]
#
# model.onnx:  61% 83.9M/137M [00:06<00:06, 8.65MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  56% 94.4M/167M [00:08<00:08, 8.34MB/s]
#
#
#
#
# model.onnx:  26% 126M/493M [00:08<00:40, 9.00MB/s]
#
#
#
#
#
#
#
# model.onnx:  48% 94.4M/198M [00:08<00:12, 8.10MB/s]
#
#
#
# model.fp16.safetensors:   9% 126M/1.39G [00:08<02:10, 9.68MB/s]
#
# model.onnx:  69% 94.4M/137M [00:06<00:03, 11.8MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  63% 105M/167M [00:08<00:05, 11.4MB/s]
#
#
# model.fp16.safetensors:  55% 136M/246M [00:08<00:10, 10.9MB/s]
#
#
#
# model.fp16.safetensors:  10% 136M/1.39G [00:08<01:39, 12.6MB/s]
# diffusion_pytorch_model.fp16.safetensors:  75% 126M/167M [00:08<00:03, 10.5MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   2% 94.4M/5.14G [00:08<08:58, 9.36MB/s]
#
#
#
#
# model.onnx:  28% 136M/493M [00:08<00:32, 10.9MB/s]
#
#
#
#
#
#
#
# model.onnx:  53% 105M/198M [00:08<00:09, 10.2MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  69% 115M/167M [00:08<00:04, 12.9MB/s]
#
# model.onnx:  77% 105M/137M [00:07<00:02, 13.1MB/s]
#
#
#
# model.fp16.safetensors:  11% 147M/1.39G [00:09<01:27, 14.2MB/s]
#
#
# model.fp16.safetensors:  60% 147M/246M [00:09<00:08, 12.4MB/s]
#
#
#
#
# model.onnx:  30% 147M/493M [00:09<00:25, 13.4MB/s]
# diffusion_pytorch_model.fp16.safetensors:  81% 136M/167M [00:09<00:02, 12.5MB/s]
#
#
#
#
#
#
#
# model.onnx:  58% 115M/198M [00:09<00:06, 12.1MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   2% 105M/5.14G [00:09<07:55, 10.6MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  75% 126M/167M [00:12<00:07, 5.84MB/s]
#
# model.onnx:  84% 115M/137M [00:11<00:03, 5.85MB/s]
#
#
# model.fp16.safetensors:  64% 157M/246M [00:13<00:15, 5.82MB/s]
#
#
#
#
# model.onnx:  32% 157M/493M [00:13<00:56, 5.96MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   2% 115M/5.14G [00:13<14:34, 5.74MB/s]
# diffusion_pytorch_model.fp16.safetensors:  88% 147M/167M [00:13<00:03, 5.83MB/s]
#
#
#
# model.fp16.safetensors:  11% 157M/1.39G [00:13<03:25, 6.00MB/s]
#
#
#
#
#
#
#
# model.onnx:  64% 126M/198M [00:12<00:12, 5.86MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  81% 136M/167M [00:13<00:03, 8.03MB/s]
#
# model.onnx:  92% 126M/137M [00:11<00:01, 8.00MB/s]
# diffusion_pytorch_model.fp16.safetensors:  94% 157M/167M [00:13<00:01, 7.96MB/s]
#
#
#
#
# model.onnx:  34% 168M/493M [00:13<00:40, 8.07MB/s]
#
#
# model.fp16.safetensors:  68% 168M/246M [00:13<00:09, 7.85MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  88% 147M/167M [00:13<00:01, 10.6MB/s]
#
#
#
# model.fp16.safetensors:  12% 168M/1.39G [00:13<02:33, 7.96MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   2% 126M/5.14G [00:13<10:55, 7.64MB/s]
#
#
#
#
#
#
#
# model.onnx:  69% 136M/198M [00:13<00:08, 7.68MB/s]
#
#
#
#
# model.onnx:  36% 178M/493M [00:13<00:28, 10.9MB/s]
#
# model.onnx: 100% 136M/137M [00:11<00:00, 10.4MB/s]
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:13<00:00, 10.4MB/s]
#
#
# model.fp16.safetensors:  72% 178M/246M [00:13<00:06, 10.4MB/s]
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  94% 157M/167M [00:13<00:00, 14.2MB/s]
#
#
#
#
# model.onnx:  38% 189M/493M [00:13<00:20, 14.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   3% 136M/5.14G [00:13<08:12, 10.2MB/s]
#
#
#
#
#
#
#
# model.onnx:  74% 147M/198M [00:13<00:05, 10.1MB/s]
#
#
#
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:13<00:00, 12.1MB/s]
#
#
#
#
#
# model.onnx:  40% 199M/493M [00:14<00:15, 18.4MB/s]
#
#
#
#
#
#
#
# model.onnx:  79% 157M/198M [00:13<00:02, 13.7MB/s]
#
#
#
# model.fp16.safetensors:  14% 189M/1.39G [00:14<01:27, 13.8MB/s]
#
#
# model.fp16.safetensors:  77% 189M/246M [00:14<00:04, 12.6MB/s]
#
#
#
#
# model.onnx: 100% 137M/137M [00:12<00:00, 11.2MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:14<00:00, 15.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   3% 147M/5.14G [00:14<06:44, 12.3MB/s]
#
#
# model.fp16.safetensors:  81% 199M/246M [00:14<00:02, 16.5MB/s]
#
#
#
# model.fp16.safetensors:  14% 199M/1.39G [00:14<01:09, 17.2MB/s]
#
#
#
#
# model.onnx:  45% 220M/493M [00:14<00:09, 28.8MB/s]
#
#
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors: 100% 167M/167M [00:14<00:00, 11.6MB/s]
#
#
#
#
# model.fp16.safetensors:  15% 210M/1.39G [00:14<01:04, 18.4MB/s]
#
#
#
#
# model.onnx:  47% 231M/493M [00:14<00:10, 24.9MB/s]
#
#
# model.fp16.safetensors:  85% 210M/246M [00:14<00:02, 16.8MB/s]
#
#
#
#
#
#
#
# model.onnx:  90% 178M/198M [00:14<00:01, 16.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   3% 168M/5.14G [00:14<04:55, 16.8MB/s]
#
#
#
# model.fp16.safetensors:  16% 220M/1.39G [00:17<02:19, 8.41MB/s]
#
#
#
#
# model.onnx:  49% 241M/493M [00:17<00:28, 8.96MB/s]
#
#
# model.fp16.safetensors:  89% 220M/246M [00:17<00:03, 7.97MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   3% 178M/5.14G [00:17<09:19, 8.86MB/s]
#
#
#
#
#
#
#
# model.onnx:  95% 189M/198M [00:17<00:01, 7.98MB/s]
#
#
#
# model.fp16.safetensors:  17% 231M/1.39G [00:18<01:47, 10.8MB/s]
#
#
# model.fp16.safetensors:  94% 231M/246M [00:18<00:01, 10.7MB/s]
#
#
#
#
# model.onnx:  51% 252M/493M [00:18<00:20, 11.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   4% 189M/5.14G [00:17<07:14, 11.4MB/s]
#
#
#
#
#
#
#
# model.onnx: 100% 198M/198M [00:17<00:00, 10.4MB/s]
#
#
#
# model.onnx: 100% 198M/198M [00:17<00:00, 11.1MB/s]
#
#
#
#
#
# model.onnx:  53% 262M/493M [00:18<00:14, 15.8MB/s]
#
#
# model.fp16.safetensors:  98% 241M/246M [00:18<00:00, 14.4MB/s]
#
#
#
#
#
# model.fp16.safetensors: 100% 246M/246M [00:18<00:00, 13.4MB/s]
# Fetching 23 files:  17% 4/23 [00:19<01:45,  5.57s/it]
#
#
#
#
# model.onnx:  55% 273M/493M [00:18<00:10, 20.9MB/s]
#
#
#
# model.fp16.safetensors:  18% 252M/1.39G [00:18<01:00, 18.7MB/s]
#
#
#
#
# model.onnx:  57% 283M/493M [00:18<00:08, 24.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   4% 220M/5.14G [00:18<03:47, 21.6MB/s]
#
#
#
# model.fp16.safetensors:  19% 262M/1.39G [00:18<00:51, 21.8MB/s]
#
#
#
#
# model.onnx:  60% 294M/493M [00:18<00:06, 31.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   5% 241M/5.14G [00:18<02:34, 31.6MB/s]
#
#
#
#
# model.onnx:  62% 304M/493M [00:18<00:04, 38.8MB/s]
#
#
#
# model.fp16.safetensors:  20% 273M/1.39G [00:18<00:42, 26.1MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   5% 252M/5.14G [00:18<02:15, 36.0MB/s]
#
#
#
#
# model.onnx:  64% 315M/493M [00:18<00:03, 46.4MB/s]
#
#
#
# model.fp16.safetensors:  20% 283M/1.39G [00:19<00:34, 32.4MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   5% 262M/5.14G [00:18<02:03, 39.5MB/s]
#
#
#
# model.fp16.safetensors:  21% 294M/1.39G [00:19<00:29, 37.2MB/s]
#
#
#
#
# model.onnx:  66% 325M/493M [00:19<00:03, 46.6MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   5% 273M/5.14G [00:19<01:46, 45.8MB/s]
#
#
#
#
# model.onnx:  68% 336M/493M [00:19<00:02, 54.5MB/s]
#
#
#
# model.fp16.safetensors:  22% 304M/1.39G [00:19<00:24, 44.0MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   6% 283M/5.14G [00:19<01:32, 52.3MB/s]
#
#
#
#
# model.onnx:  70% 346M/493M [00:19<00:02, 62.1MB/s]
#
#
#
# model.fp16.safetensors:  23% 315M/1.39G [00:19<00:20, 51.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   6% 294M/5.14G [00:19<01:21, 59.1MB/s]
#
#
#
#
# model.onnx:  75% 367M/493M [00:19<00:01, 77.3MB/s]
#
#
#
# model.fp16.safetensors:  24% 336M/1.39G [00:19<00:15, 68.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   6% 315M/5.14G [00:19<01:02, 77.1MB/s]
#
#
#
#
# model.onnx:  77% 377M/493M [00:19<00:01, 80.0MB/s]
#
#
#
# model.fp16.safetensors:  26% 357M/1.39G [00:19<00:12, 83.1MB/s]
#
#
#
#
# model.onnx:  79% 388M/493M [00:19<00:01, 84.4MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   7% 336M/5.14G [00:19<00:55, 86.4MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   7% 346M/5.14G [00:19<00:53, 89.3MB/s]
#
#
#
# model.fp16.safetensors:  27% 377M/1.39G [00:19<00:11, 91.6MB/s]
#
#
#
#
# model.onnx:  83% 409M/493M [00:19<00:00, 96.3MB/s]
#
#
#
# model.fp16.safetensors:  28% 388M/1.39G [00:20<00:10, 91.1MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   7% 367M/5.14G [00:19<00:47, 99.4MB/s]
#
#
#
#
# model.onnx:  87% 430M/493M [00:20<00:00, 103MB/s]
#
#
#
# model.fp16.safetensors:  29% 409M/1.39G [00:20<00:10, 97.4MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   8% 388M/5.14G [00:20<00:46, 103MB/s]
#
#
#
#
# model.onnx:  92% 451M/493M [00:20<00:00, 102MB/s]
#
#
#
# model.fp16.safetensors:  30% 419M/1.39G [00:20<00:10, 95.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   8% 409M/5.14G [00:20<00:44, 105MB/s]
#
#
#
#
# model.onnx:  94% 461M/493M [00:20<00:00, 98.2MB/s]
#
#
#
# model.fp16.safetensors:  32% 440M/1.39G [00:20<00:09, 99.5MB/s]
#
#
#
#
# model.onnx:  96% 472M/493M [00:20<00:00, 91.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   8% 430M/5.14G [00:20<00:48, 97.0MB/s]
#
#
#
#
# model.onnx:  98% 482M/493M [00:20<00:00, 87.5MB/s]
#
#
#
# model.fp16.safetensors:  33% 461M/1.39G [00:20<00:09, 98.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   9% 440M/5.14G [00:20<00:49, 94.4MB/s]
#
#
#
#
# model.onnx: 100% 493M/493M [00:20<00:00, 84.8MB/s]
#
#
#
# model.onnx: 100% 493M/493M [00:21<00:00, 23.5MB/s]
#
#
#
#
#
#
# Fetching 23 files:  22% 5/23 [00:21<01:25,  4.72s/it]
#
#
#
# model.fp16.safetensors:  35% 482M/1.39G [00:21<00:09, 94.8MB/s]
#
#
#
# model.fp16.safetensors:  35% 493M/1.39G [00:21<00:09, 96.2MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:   9% 472M/5.14G [00:21<00:47, 98.8MB/s]
#
#
#
# model.fp16.safetensors:  37% 514M/1.39G [00:21<00:08, 103MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  10% 493M/5.14G [00:21<00:44, 103MB/s]
#
#
#
# model.fp16.safetensors:  38% 535M/1.39G [00:21<00:07, 112MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  10% 514M/5.14G [00:21<00:41, 112MB/s]
#
#
#
# model.fp16.safetensors:  40% 556M/1.39G [00:21<00:07, 117MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  10% 535M/5.14G [00:21<00:41, 110MB/s]
#
#
#
# model.fp16.safetensors:  42% 577M/1.39G [00:21<00:07, 114MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  11% 556M/5.14G [00:21<00:41, 111MB/s]
#
#
#
# model.fp16.safetensors:  43% 598M/1.39G [00:22<00:06, 114MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  11% 577M/5.14G [00:21<00:41, 111MB/s]
#
#
#
# model.fp16.safetensors:  45% 619M/1.39G [00:22<00:06, 113MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  12% 598M/5.14G [00:22<00:40, 112MB/s]
#
#
#
# model.fp16.safetensors:  46% 640M/1.39G [00:22<00:06, 113MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  12% 619M/5.14G [00:22<00:40, 113MB/s]
#
#
#
# model.fp16.safetensors:  48% 661M/1.39G [00:22<00:06, 114MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  12% 640M/5.14G [00:22<00:39, 114MB/s]
#
#
#
# model.fp16.safetensors:  49% 682M/1.39G [00:22<00:06, 114MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  13% 661M/5.14G [00:22<00:36, 122MB/s]
#
#
#
# model.fp16.safetensors:  51% 703M/1.39G [00:22<00:05, 119MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  13% 682M/5.14G [00:22<00:35, 126MB/s]
#
#
#
# model.fp16.safetensors:  52% 724M/1.39G [00:23<00:05, 126MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  14% 703M/5.14G [00:22<00:33, 132MB/s]
#
#
#
# model.fp16.safetensors:  54% 744M/1.39G [00:23<00:04, 130MB/s]
#
#
#
# model.fp16.safetensors:  55% 765M/1.39G [00:23<00:04, 141MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  14% 724M/5.14G [00:23<00:46, 95.7MB/s]
#
#
#
# model.fp16.safetensors:  57% 786M/1.39G [00:23<00:04, 139MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  14% 744M/5.14G [00:27<05:19, 13.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  15% 755M/5.14G [00:28<04:37, 15.8MB/s]
#
#
#
# model.fp16.safetensors:  58% 807M/1.39G [00:28<00:43, 13.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  15% 776M/5.14G [00:28<03:20, 21.8MB/s]
#
#
#
# model.fp16.safetensors:  59% 818M/1.39G [00:28<00:36, 15.6MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  16% 797M/5.14G [00:28<02:26, 29.7MB/s]
#
#
#
# model.fp16.safetensors:  60% 839M/1.39G [00:28<00:24, 22.3MB/s]
#
#
#
# model.fp16.safetensors:  62% 860M/1.39G [00:28<00:17, 30.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  16% 818M/5.14G [00:28<01:52, 38.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  16% 828M/5.14G [00:28<01:44, 41.1MB/s]
#
#
#
# model.fp16.safetensors:  63% 881M/1.39G [00:29<00:13, 38.9MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  16% 839M/5.14G [00:28<01:33, 46.1MB/s]
#
#
#
# ...
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  40% 2.08G/5.14G [00:48<00:27, 109MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  41% 2.10G/5.14G [00:48<00:24, 126MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  41% 2.12G/5.14G [00:48<00:21, 139MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  42% 2.14G/5.14G [00:49<00:21, 139MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  42% 2.16G/5.14G [00:49<00:20, 143MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  42% 2.18G/5.14G [00:49<00:20, 147MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  43% 2.20G/5.14G [00:49<00:19, 147MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  43% 2.22G/5.14G [00:49<00:18, 157MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  44% 2.24G/5.14G [00:49<00:17, 169MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  44% 2.26G/5.14G [00:49<00:16, 176MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  45% 2.29G/5.14G [00:49<00:15, 183MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  45% 2.31G/5.14G [00:50<00:15, 188MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  45% 2.33G/5.14G [00:50<00:15, 187MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  46% 2.35G/5.14G [00:50<00:16, 172MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  46% 2.37G/5.14G [00:50<00:16, 168MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  47% 2.39G/5.14G [00:50<00:16, 165MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  47% 2.41G/5.14G [00:50<00:16, 161MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  47% 2.43G/5.14G [00:52<01:39, 27.1MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  48% 2.45G/5.14G [00:53<01:14, 36.0MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  48% 2.47G/5.14G [00:53<00:59, 45.1MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  49% 2.50G/5.14G [00:53<00:44, 58.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  49% 2.53G/5.14G [00:53<00:31, 82.2MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  50% 2.56G/5.14G [00:53<00:24, 105MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  50% 2.58G/5.14G [00:53<00:22, 112MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  51% 2.60G/5.14G [00:53<00:20, 127MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  51% 2.62G/5.14G [00:54<00:17, 142MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  51% 2.64G/5.14G [00:54<00:16, 154MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  52% 2.66G/5.14G [00:54<00:14, 166MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  52% 2.68G/5.14G [00:54<00:14, 173MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  53% 2.72G/5.14G [00:54<00:12, 189MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  53% 2.75G/5.14G [00:54<00:11, 200MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  54% 2.78G/5.14G [00:54<00:11, 199MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  55% 2.80G/5.14G [00:54<00:11, 199MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  55% 2.82G/5.14G [00:55<00:11, 198MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  55% 2.84G/5.14G [00:55<00:11, 195MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  56% 2.86G/5.14G [00:57<01:32, 24.6MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  56% 2.89G/5.14G [00:58<01:00, 36.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  57% 2.92G/5.14G [00:58<00:50, 43.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  57% 2.94G/5.14G [00:58<00:39, 55.5MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  58% 2.97G/5.14G [00:58<00:28, 76.1MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  58% 3.00G/5.14G [00:58<00:21, 97.2MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  59% 3.02G/5.14G [00:58<00:19, 107MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  59% 3.04G/5.14G [00:58<00:17, 121MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  60% 3.07G/5.14G [00:59<00:14, 143MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  60% 3.10G/5.14G [00:59<00:12, 159MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  61% 3.14G/5.14G [00:59<00:11, 174MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  62% 3.17G/5.14G [00:59<00:10, 186MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  62% 3.19G/5.14G [00:59<00:10, 187MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  62% 3.21G/5.14G [00:59<00:10, 190MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  63% 3.23G/5.14G [00:59<00:09, 191MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  63% 3.25G/5.14G [00:59<00:09, 190MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  64% 3.27G/5.14G [01:00<00:09, 190MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  64% 3.29G/5.14G [01:00<00:09, 190MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  65% 3.31G/5.14G [01:00<00:09, 191MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  65% 3.33G/5.14G [01:00<00:09, 193MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  65% 3.36G/5.14G [01:00<00:09, 193MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  66% 3.38G/5.14G [01:00<00:09, 195MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  66% 3.40G/5.14G [01:00<00:09, 191MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  67% 3.42G/5.14G [01:00<00:09, 183MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  67% 3.44G/5.14G [01:00<00:09, 179MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  67% 3.46G/5.14G [01:01<00:09, 176MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  68% 3.48G/5.14G [01:01<00:09, 182MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  68% 3.50G/5.14G [01:01<00:08, 187MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  69% 3.52G/5.14G [01:01<00:08, 187MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  69% 3.54G/5.14G [01:01<00:08, 190MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  69% 3.57G/5.14G [01:01<00:08, 181MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  70% 3.59G/5.14G [01:01<00:08, 175MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  70% 3.61G/5.14G [01:01<00:08, 172MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  71% 3.63G/5.14G [01:02<00:09, 165MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  71% 3.65G/5.14G [01:02<00:08, 167MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  71% 3.67G/5.14G [01:03<00:23, 62.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  72% 3.69G/5.14G [01:03<00:18, 77.9MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  72% 3.71G/5.14G [01:03<00:15, 94.6MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  73% 3.73G/5.14G [01:03<00:12, 111MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  73% 3.75G/5.14G [01:03<00:11, 123MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  74% 3.77G/5.14G [01:03<00:09, 139MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  74% 3.80G/5.14G [01:03<00:12, 104MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  74% 3.82G/5.14G [01:04<00:11, 119MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  75% 3.84G/5.14G [01:04<00:09, 134MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  75% 3.86G/5.14G [01:04<00:08, 144MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  76% 3.88G/5.14G [01:04<00:08, 154MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  76% 3.90G/5.14G [01:04<00:07, 161MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  76% 3.92G/5.14G [01:04<00:07, 168MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  77% 3.95G/5.14G [01:04<00:06, 186MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  78% 3.98G/5.14G [01:04<00:05, 197MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  78% 4.02G/5.14G [01:05<00:05, 203MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  79% 4.04G/5.14G [01:05<00:05, 203MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  79% 4.06G/5.14G [01:05<00:05, 193MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  79% 4.08G/5.14G [01:05<00:05, 191MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  80% 4.10G/5.14G [01:05<00:05, 195MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  80% 4.12G/5.14G [01:05<00:05, 195MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  81% 4.14G/5.14G [01:07<00:28, 34.8MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  81% 4.16G/5.14G [01:07<00:21, 45.6MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  81% 4.18G/5.14G [01:07<00:17, 54.0MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  82% 4.20G/5.14G [01:07<00:13, 68.9MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  82% 4.24G/5.14G [01:07<00:09, 93.7MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  83% 4.27G/5.14G [01:08<00:07, 117MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  84% 4.29G/5.14G [01:08<00:06, 121MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  84% 4.32G/5.14G [01:08<00:05, 145MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  85% 4.34G/5.14G [01:08<00:05, 150MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  85% 4.36G/5.14G [01:08<00:04, 160MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  85% 4.38G/5.14G [01:08<00:04, 166MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  86% 4.40G/5.14G [01:08<00:04, 173MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  86% 4.42G/5.14G [01:08<00:03, 179MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  87% 4.45G/5.14G [01:09<00:03, 183MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  87% 4.47G/5.14G [01:09<00:03, 189MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  87% 4.49G/5.14G [01:09<00:03, 192MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  88% 4.52G/5.14G [01:09<00:03, 202MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  89% 4.55G/5.14G [01:09<00:02, 209MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  89% 4.58G/5.14G [01:09<00:02, 208MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  90% 4.60G/5.14G [01:09<00:02, 195MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  90% 4.62G/5.14G [01:09<00:02, 192MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  90% 4.65G/5.14G [01:10<00:02, 191MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  91% 4.67G/5.14G [01:10<00:02, 193MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  91% 4.69G/5.14G [01:12<00:14, 30.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  92% 4.71G/5.14G [01:12<00:13, 30.9MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  92% 4.73G/5.14G [01:13<00:09, 40.6MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  93% 4.75G/5.14G [01:13<00:07, 49.4MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  93% 4.77G/5.14G [01:13<00:05, 63.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  94% 4.80G/5.14G [01:13<00:03, 87.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  94% 4.82G/5.14G [01:13<00:03, 102MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  94% 4.84G/5.14G [01:13<00:02, 110MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  95% 4.87G/5.14G [01:13<00:02, 122MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  95% 4.89G/5.14G [01:14<00:01, 134MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  96% 4.91G/5.14G [01:14<00:01, 146MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  96% 4.93G/5.14G [01:14<00:01, 160MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  96% 4.95G/5.14G [01:14<00:01, 155MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  97% 4.97G/5.14G [01:14<00:01, 146MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  97% 4.99G/5.14G [01:14<00:00, 150MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  98% 5.01G/5.14G [01:14<00:00, 154MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  98% 5.03G/5.14G [01:15<00:01, 60.0MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  98% 5.05G/5.14G [01:18<00:04, 18.3MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors:  99% 5.09G/5.14G [01:18<00:01, 28.6MB/s]
#
#
#
#
#
# diffusion_pytorch_model.fp16.safetensors: 100% 5.14G/5.14G [01:19<00:00, 64.9MB/s]
# Fetching 23 files: 100% 23/23 [01:20<00:00,  3.48s/it]
# The config attributes {'add_watermarker': None} were passed to StableDiffusionXLPipeline, but are not expected and will be ignored. Please verify your model_index.json configuration file.
# Keyword arguments {'add_watermarker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
# The config attributes {'force_upcast': True} were passed to AutoencoderKL, but are not expected and will be ignored. Please verify your config.json configuration file.
# U-Net converted to original U-Net
# load VAE: stabilityai/sdxl-vae
# config.json: 100% 607/607 [00:00<00:00, 3.41MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 164MB/s]
# additional VAE loaded
# Enable SDPA for U-Net
# import network module: networks.lora
# [Dataset 0]
# caching latents.
# checking cache validity...
# 100% 12/12 [00:00<00:00, 1505.22it/s]
# caching latents...
# 100% 12/12 [00:08<00:00,  1.39it/s]
# create LoRA network. base dim (rank): 32, alpha: 32
# neuron dropout: p=None, rank dropout: p=None, module dropout: p=None
# create LoRA for Text Encoder 1:
# create LoRA for Text Encoder 2:
# create LoRA for Text Encoder: 264 modules.
# create LoRA for U-Net: 722 modules.
# enable LoRA for text encoder
# enable LoRA for U-Net
# prepare optimizer, data loader etc.
# use Prodigy optimizer | {'decouple': True, 'weight_decay': 0.01, 'betas': [0.9, 0.999], 'd_coef': 2, 'use_bias_correction': True, 'safeguard_warmup': True}
# Using decoupled weight decay
# override steps. steps for 10 epochs is / 指定エポックまでのステップ数: 600
# running training / 学習開始
#   num train images * repeats / 学習画像の数×繰り返し回数: 240
#   num reg images / 正則化画像の数: 0
#   num batches per epoch / 1epochのバッチ数: 60
#   num epochs / epoch数: 10
#   batch size per device / バッチサイズ: 4
#   gradient accumulation steps / 勾配を合計するステップ数 = 1
#   total optimization steps / 学習ステップ数: 600
# steps:   0% 0/600 [00:00<?, ?it/s]
# epoch 1/10
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# steps:  10% 60/600 [03:24<30:37,  3.40s/it, loss=0.103]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-01.safetensors
#
# epoch 2/10
# steps:  20% 120/600 [06:49<27:18,  3.41s/it, loss=0.0973]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-02.safetensors
#
# epoch 3/10
# steps:  30% 180/600 [10:14<23:54,  3.41s/it, loss=0.0932]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-03.safetensors
#
# epoch 4/10
# steps:  40% 240/600 [13:39<20:28,  3.41s/it, loss=0.0995]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-04.safetensors
#
# epoch 5/10
# steps:  50% 300/600 [17:03<17:03,  3.41s/it, loss=0.1]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-05.safetensors
#
# epoch 6/10
# steps:  60% 360/600 [20:29<13:39,  3.41s/it, loss=0.0792]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-06.safetensors
#
# epoch 7/10
# steps:  70% 420/600 [23:53<10:14,  3.41s/it, loss=0.0848]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-07.safetensors
#
# epoch 8/10
# steps:  80% 480/600 [27:17<06:49,  3.41s/it, loss=0.091]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-08.safetensors
#
# epoch 9/10
# steps:  90% 540/600 [30:43<03:24,  3.41s/it, loss=0.076]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-09.safetensors
#
# epoch 10/10
# steps: 100% 600/600 [34:07<00:00,  3.41s/it, loss=0.0908]
# saving checkpoint: /content/drive/MyDrive/Loras/Ducreux-colab/output/Ducreux-colab-10.safetensors
# model saved.
# steps: 100% 600/600 [34:10<00:00,  3.42s/it, loss=0.0908]
# ### ✅ Done! [Go download your Lora from Google Drive](https://drive.google.com/drive/my-drive)
# ### There will be several files, you should try the latest version (the file with the largest number next to it)

# %% [markdown]
# ## *️⃣ Extras
#
# You can run these before starting the training.

# %% [markdown]
# ### 📚 Multiple folders in dataset
# Below is a template allowing you to define multiple folders in your dataset. You must include the location of each folder and you can set different number of repeats for each one. To add more folders simply copy and paste the sections starting with `[[datasets.subsets]]`.
#
# When enabling this, the number of repeats set in the main cell will be ignored, and the main folder set by the project name will also be ignored.
#
# You can make one of them a regularization folder by adding `is_reg = true`
# You can also set different `keep_tokens`, `flip_aug`, etc.

# %%
custom_dataset = """
[[datasets]]

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/example/dataset/good_images"
num_repeats = 3

[[datasets.subsets]]
image_dir = "/content/drive/MyDrive/Loras/example/dataset/normal_images"
num_repeats = 1

"""

# %%
custom_dataset = None

# %%
#@markdown ### 📂 Unzip dataset
#@markdown It's much slower to upload individual files to your Drive, so you may want to upload a zip if you have your dataset in your computer.
zip = "/content/drive/MyDrive/my_dataset.zip" #@param {type:"string"}
extract_to = "/content/drive/MyDrive/Loras/example/dataset" #@param {type:"string"}

import os, zipfile

if not os.path.exists('/content/drive'):
  from google.colab import drive
  print("📂 Connecting to Google Drive...")
  drive.mount('/content/drive')

os.makedirs(extract_to, exist_ok=True)

with zipfile.ZipFile(zip, 'r') as f:
  f.extractall(extract_to)

print("✅ Done")

# %%
#@markdown ### 🔢 Count datasets
#@markdown Google Drive makes it impossible to count the files in a folder, so this will show you the file counts in all folders and subfolders.
folder = "/content/drive/MyDrive/Loras" #@param {type:"string"}

import os
from google.colab import drive

if not os.path.exists('/content/drive'):
    print("📂 Connecting to Google Drive...\n")
    drive.mount('/content/drive')

tree = {}
exclude = ("_logs", "/output")
for i, (root, dirs, files) in enumerate(os.walk(folder, topdown=True)):
  dirs[:] = [d for d in dirs if all(ex not in d for ex in exclude)]
  images = len([f for f in files if f.lower().endswith((".png", ".jpg", ".jpeg"))])
  captions = len([f for f in files if f.lower().endswith(".txt")])
  others = len(files) - images - captions
  path = root[folder.rfind("/")+1:]
  tree[path] = None if not images else f"{images:>4} images | {captions:>4} captions |"
  if tree[path] and others:
    tree[path] += f" {others:>4} other files"

pad = max(len(k) for k in tree)
print("\n".join(f"📁{k.ljust(pad)} | {v}" for k, v in tree.items() if v))

# %% [markdown]
# # 📈 Plot training results
# You can do this after running the trainer. You don't need this unless you know what you're doing.
# The first cell below may fail to load all your logs. Keep trying the second cell until all data has loaded.

# %%
# %load_ext tensorboard
# %tensorboard --logdir={log_folder}/

# %%
from tensorboard import notebook
notebook.display(port=6006, height=800)
